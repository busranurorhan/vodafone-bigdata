# %%
import pandas as pd

worldDF = pd.read_csv('datasets/world.txt', delimiter=',',header=None, names=['Country','Continent','CapitalCity','Population'])
#worldDF.columns=['Country','Continent','CapitalCity','Population']
worldDF.head()
# Out:
#        Country Continent       CapitalCity  Population
# 0  Afghanistan      Asia             Kabul    29863010
# 1      Albania    Europe            Tirana     3129678
# 2      Algeria    Africa           Algiers    32853800
# 3      Andorra    Europe  Andorra la Vella       67151
# 4       Angola    Africa            Luanda    15941390

# %%
asiaDF = worldDF[worldDF['Continent']=='Asia'] #Filter
print(len(asiaDF))
asiaDF.head()
# Out:
# 49
#         Country Continent CapitalCity  Population
# 0   Afghanistan      Asia       Kabul    29863010
# 7       Armenia      Asia     Yerevan     3016312
# 10   Azerbaijan      Asia        Baku     8410801
# 12      Bahrain      Asia      Manama      726617
# 13   Bangladesh      Asia       Dhaka   141822300

# %%
asiaDF[['Country','Population']].head()
# Out:
#         Country  Population
# 0   Afghanistan    29863010
# 7       Armenia     3016312
# 10   Azerbaijan     8410801
# 12      Bahrain      726617
# 13   Bangladesh   141822300

# %%
asiaDF['NewPopulation'] = asiaDF["Population"]*2
asiaDF.head()
#Tüm versiyonlarda çalışan hali Google drive a koyulacak
# Out:
# <ipython-input-52-f6d877a3d467>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asiaDF['NewPopulation'] = asiaDF["Population"]*2
#         Country Continent CapitalCity  Population  NewPopulation
# 0   Afghanistan      Asia       Kabul    29863010       59726020
# 7       Armenia      Asia     Yerevan     3016312        6032624
# 10   Azerbaijan      Asia        Baku     8410801       16821602
# 12      Bahrain      Asia      Manama      726617        1453234
# 13   Bangladesh      Asia       Dhaka   141822300      283644600

# %%
asiaDF.iloc[[3]]
# Out:
#     Country Continent CapitalCity  Population  NewPopulation
# 12  Bahrain      Asia      Manama      726617        1453234

# %%
actorsDF = pd.read_csv('datasets/join-actors.txt')
seriesDF = pd.read_csv('datasets/join-series.txt')
actorsDF.head()
# Out:
#    id              name  movieid
# 0   1         Eric Dane      2.0
# 1   2      Adam Baldwin      2.0
# 2   3   Charles Parnell      2.0
# 3   4       Billy Burke      6.0
# 4   5  Tracy Spiridakos      6.0

# %%
seriesDF.head()
# Out:
#    movieid           moviename
# 0        1       Lethal Weapon
# 1        2       The Last Ship
# 2        3  Person of Interest
# 3        4     Game of Thrones
# 4        5        Flashforward

# %%
joinedDF = pd.merge(seriesDF,actorsDF,on='movieid',how='outer')
joinedDF.head(100)
# Out:
#     movieid           moviename    id                   name
# 0       1.0       Lethal Weapon   7.0           Damon Wayans
# 1       1.0       Lethal Weapon   8.0        Clayne Crawford
# 2       2.0       The Last Ship   1.0              Eric Dane
# 3       2.0       The Last Ship   2.0           Adam Baldwin
# 4       2.0       The Last Ship   3.0        Charles Parnell
# 5       3.0  Person of Interest  12.0           Jim Caviezel
# 6       3.0  Person of Interest  13.0        Michael Emerson
# 7       3.0  Person of Interest  14.0       Taraji P. Henson
# 8       4.0     Game of Thrones  15.0         Peter Dinklage
# 9       4.0     Game of Thrones  16.0          Emilia Clarke
# 10      4.0     Game of Thrones  17.0          Kit Harington
# 11      4.0     Game of Thrones  18.0  Nikolaj Coster-Waldau
# 12      5.0        Flashforward   9.0         Joseph Fiennes
# 13      5.0        Flashforward  10.0         Jack Davenport
# ...

# %%
#matplotlib /seaborn (Veri görselleştirme)
import matplotlib.pyplot as plt
import numpy as np

pointsDF = np.loadtxt('datasets/points.txt',delimiter=',')
x = pointsDF[:,0]
y = pointsDF[:,1]

plt.scatter(x,y)
plt.show()

# %%
#link : https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html

labels = 'Gömlek', 'Tshirt', 'Şort', 'Ayakkabı'
sizes = [23, 47, 15, 5]
explode = (0, 0, 0, 0.3)  
plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
plt.show()
